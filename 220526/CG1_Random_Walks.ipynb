# %% [markdown]
# # Probability via Computation

# %% [markdown]
# * Random interactions among Agents
# * Brownian Motion
# * Random Collisions of Molecules
#
# ## Random Walks ##
#
# Particles moving randomly
# * The simplest possible model is a 1D random walk
#
# ${x(t) = x(t-1) \pm 1}$
#
# * Markov Chain

# %%
import Pkg; Pkg.add("Interact")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %%
function jump()
    a = rand([-1,1])
    return a
end
# Out:
# jump (generic function with 1 method)

# %%
jump()
# Out:
# 1

# %%
function random_walk(n)
    x = 0
    positions = [x]
    
    for i = 1:n
        x += jump()
        push!(positions, x)
    end
    
    return positions
    
end
# Out:
# random_walk (generic function with 1 method)

# %%
pos1 = random_walk(20);

# %%
using Interact; using Plots;
N = 100
positions = random_walk(N)

    @manipulate for n in 1:N
        plot(positions[1:n], m=:o)
    end
# Out:
# WebIO._IJuliaInit()
# ...

# %%
my_plot = plot(leg=false)
n_people = 1000

for i in 1:n_people
    plot!(random_walk(50))
end

my_plot

# %%
function final_position(n)
    a = random_walk(n)
    return a[end]
end
# Out:
# final_position (generic function with 1 method)

# %%
final_position(10)
# Out:
# -4

# %%
Pkg.add("StatsBase"); using StatsBase
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %%
function pdf(T,N)
my_data = [final_position(T) for i in 1:N]
counts = countmap(my_data)
    histogram(my_data, xlim=(-30,30))
end
    N = 1000
    @manipulate for n in 1:N
        pdf(2,n)
    end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["n"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 1000, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(
# ...

# %%
    T = 1000
    @manipulate for t in 1:T
        pdf(t,1000)
    end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["t"], Dict{Symbol, Any}(:className => "interact ", :style => Dict{Any, Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol, Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol, Any}(:max => 1000, :min => 1, :attributes => Dict{Any, Any}(:type => "range", Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}", "orient" => "horizontal"), :step => 1, :className => "slider slider is-fullwidth", :style => Dict{Any, Any}()))], Dict{Symbol, Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol, Any}(
# ...

# %%
N = 100
res = zeros(100)
for t in 1:100
my_data = [final_position(j) for j in 1:N]
res[t] = std(my_data)
end

plot(res)

# %%
n_steps = collect(1:1000)
b = zeros(1000)
for i in 1:1000
a = zeros(100)
[ a[j] = final_position(n_steps[i]) for j in 1:100]
b[i] = std(a)
end

# %%
plot(n_steps,b)
